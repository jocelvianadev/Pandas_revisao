# %% [markdown]
# # _Pandas - revisão_
# _Jocel Viana Alcântara_
# _Data: 13/01/2023_

# %%
# Importação
import pandas as pd

# %%
# Carregar base de dados
df = pd.read_csv('Credit.csv')
df.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# ...

# %%
# Dimensões
df.shape
# Out:
# (1000, 21)

# %%
# Resumo estatístico
df.describe()
# Out:
#           duration  credit_amount  installment_commitment  residence_since  \
# count  1000.000000    1000.000000             1000.000000      1000.000000
# mean     20.903000    3271.258000                2.973000         2.845000
# std      12.058814    2822.736876                1.118715         1.103718
# min       4.000000     250.000000                1.000000         1.000000
# 25%      12.000000    1365.500000                2.000000         2.000000
# 50%      18.000000    2319.500000                3.000000         3.000000
# 75%      24.000000    3972.250000                4.000000         4.000000
# max      72.000000   18424.000000                4.000000         4.000000
#
#                age  existing_credits  num_dependents
# count  1000.000000       1000.000000     1000.000000
# mean     35.546000          1.407000        1.155000
# std      11.375469          0.577654        0.362086
# min      19.000000          1.000000        1.000000
# ...

# %%
# Filtrar por nome da coluna
df['credit_amount']
# Out:
# 0      1169
# 1      5951
# 2      2096
# 3      7882
# 4      4870
#        ...
# 995    1736
# 996    3857
# 997     804
# 998    1845
# 999    4576
# Name: credit_amount, Length: 1000, dtype: int64

# %%
# Filtrar linhas por índice
df.loc[1:3]
# Out:
#   checking_status  duration                    credit_history  \
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
#
#                purpose  credit_amount savings_status employment  \
# 1             radio/tv           5951           <100     1<=X<4
# 2            education           2096           <100     4<=X<7
# 3  furniture/equipment           7882           <100     4<=X<7
#
#    installment_commitment       personal_status other_parties  ...  \
# 1                       2  'female div/dep/mar'          none  ...
# 2                       2         'male single'          none  ...
# 3                       2         'male single'     guarantor  ...
#
#    property_magnitude age  other_payment_plans     housing existing_credits  \
# 1       'real estate'  22                 none         own                1
# ...

# %%
# Filtro - linhas 2 e 3
df.loc[[2,7]]
# Out:
#   checking_status  duration                    credit_history     purpose  \
# 2   'no checking'        12  'critical/other existing credit'   education
# 7        0<=X<200        36                   'existing paid'  'used car'
#
#    credit_amount savings_status employment  installment_commitment  \
# 2           2096           <100     4<=X<7                       2
# 7           6948           <100     1<=X<4                       2
#
#   personal_status other_parties  ...  property_magnitude age  \
# 2   'male single'          none  ...       'real estate'  49
# 7   'male single'          none  ...                 car  35
#
#    other_payment_plans housing existing_credits                          job  \
# 2                 none     own                1         'unskilled resident'
# 7                 none    rent                1  'high qualif/self emp/mgmt'
#
#   num_dependents  own_telephone foreign_worker class
# 2              2           none            yes  good
# ...

# %%
# Filtro
df.loc[df['purpose'] == 'education'].head()
# Out:
#    checking_status  duration                    credit_history    purpose  \
# 2    'no checking'        12  'critical/other existing credit'  education
# 5    'no checking'        36                   'existing paid'  education
# 36   'no checking'        48  'critical/other existing credit'  education
# 68   'no checking'        36                   'existing paid'  education
# 74              <0        36                   'existing paid'  education
#
#     credit_amount      savings_status employment  installment_commitment  \
# 2            2096                <100     4<=X<7                       2
# 5            9055  'no known savings'     1<=X<4                       2
# 36           6110                <100     1<=X<4                       1
# 68           1819                <100     1<=X<4                       4
# 74           1977  'no known savings'        >=7                       4
#
#    personal_status other_parties  ...   property_magnitude age  \
# ...

# %%
# Outra condição
df.loc[df['credit_amount'] < 2000]
# Out:
#     checking_status  duration                    credit_history  \
# 0                <0         6  'critical/other existing credit'
# 10         0<=X<200        12                   'existing paid'
# 12         0<=X<200        12                   'existing paid'
# 13               <0        24  'critical/other existing credit'
# 14               <0        15                   'existing paid'
# ..              ...       ...                               ...
# 991   'no checking'        15                        'all paid'
# 992              <0        18                   'existing paid'
# 995   'no checking'        12                   'existing paid'
# 997   'no checking'        12                   'existing paid'
# 998              <0        45                   'existing paid'
#
#                  purpose  credit_amount      savings_status employment  \
# 0               radio/tv           1169  'no known savings'        >=7
# ...

# %%
# Gerando outro dataframe
df2 = df.loc[df['credit_amount'] < 2000]
df.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# ...

# %%
# Filtrando...trazendo apenas algumas colunas
df3 = df[['duration', 'savings_status', 'credit_amount']].loc[df['credit_amount'] < 1000]
df3
# Out:
#      duration      savings_status  credit_amount
# 26          6                <100            426
# 27         12              >=1000            409
# 39          9                <100            458
# 55          6  'no known savings'            783
# 71          7  'no known savings'            730
# ..        ...                 ...            ...
# 936         9                <100            745
# 942        24  'no known savings'            929
# 964         6                <100            454
# 976         6                <100            753
# 997        12                <100            804
#
# [116 rows x 3 columns]

# %% [markdown]
# #### _Series_

# %%
# Serie, única coluna
# Pode ser criada a partir de listas
lista1 = [12,34,23,65,78,56,43,67,89,90]
serie1 = pd.Series(lista1)
serie1
# Out:
# 0    12
# 1    34
# 2    23
# 3    65
# 4    78
# 5    56
# 6    43
# 7    67
# 8    89
# 9    90
# dtype: int64

# %%
# Criação a partir de um array numpy
import numpy as np
array1 = np.array([23,67,54,78,90,21,45,67,54,678])
serie2 = pd.Series(array1)
serie2
# Out:
# 0     23
# 1     67
# 2     54
# 3     78
# 4     90
# 5     21
# 6     45
# 7     67
# 8     54
# 9    678
# dtype: int32

# %%
# Criar uma serie a partir de um dataframe
serie3 = pd.Series(df['purpose'])
print(serie3)
print(type(serie3))
# Out:
# 0                 radio/tv
# 1                 radio/tv
# 2                education
# 3      furniture/equipment
# 4                'new car'
#               ...
# 995    furniture/equipment
# 996             'used car'
# 997               radio/tv
# 998               radio/tv
# 999             'used car'
# Name: purpose, Length: 1000, dtype: object
# <class 'pandas.core.series.Series'>

# %%
# Renomear colunas
df.rename(columns={"personal_status":"Status pessoal", "credit_history":"Historico de credito"}, inplace=True)
df.head()
# Out:
#   checking_status  duration              Historico de credito  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment        Status pessoal other_parties  ...  \
# 0                       4         'male single'          none  ...
# ...

# %%
# Excluindo colunas
df.drop('checking_status', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [48], in <cell line: 2>()
#       1 # Excluindo colunas
# ----> 2 df.drop('checking_status', axis=1, inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
# ...

# %%
df.head()
# Out:
#    duration              Historico de credito              purpose  \
# 0         6  'critical/other existing credit'             radio/tv
# 1        48                   'existing paid'             radio/tv
# 2        12  'critical/other existing credit'            education
# 3        42                   'existing paid'  furniture/equipment
# 4        24              'delayed previously'            'new car'
#
#    credit_amount      savings_status employment  installment_commitment  \
# 0           1169  'no known savings'        >=7                       4
# 1           5951                <100     1<=X<4                       2
# 2           2096                <100     4<=X<7                       2
# 3           7882                <100     4<=X<7                       2
# 4           4870                <100     1<=X<4                       3
#
#          Status pessoal other_parties  residence_since   property_magnitude  \
# ...

# %%
# Verificar dados nulos
df.isnull().sum()
# Out:
# duration                  0
# Historico de credito      0
# purpose                   0
# credit_amount             0
# savings_status            0
# employment                0
# installment_commitment    0
# Status pessoal            0
# other_parties             0
# residence_since           0
# property_magnitude        0
# age                       0
# other_payment_plans       0
# housing                   0
# existing_credits          0
# job                       0
# num_dependents            0
# own_telephone             0
# foreign_worker            0
# class                     0
# dtype: int64

# %%
# Excluir colunas com Na's
df.dropna()
# Out:
#      duration              Historico de credito              purpose  \
# 0           6  'critical/other existing credit'             radio/tv
# 1          48                   'existing paid'             radio/tv
# 2          12  'critical/other existing credit'            education
# 3          42                   'existing paid'  furniture/equipment
# 4          24              'delayed previously'            'new car'
# ..        ...                               ...                  ...
# 995        12                   'existing paid'  furniture/equipment
# 996        30                   'existing paid'           'used car'
# 997        12                   'existing paid'             radio/tv
# 998        45                   'existing paid'             radio/tv
# 999        45  'critical/other existing credit'           'used car'
#
#      credit_amount      savings_status  employment  installment_commitment  \
# ...

# %%
# preencher dados faltantes
df['duration'].fillna(0,inplace=True)

# %%
## iloc
df.iloc[0:3, 0:5]
# Out:
#    duration              Historico de credito    purpose  credit_amount  \
# 0         6  'critical/other existing credit'   radio/tv           1169
# 1        48                   'existing paid'   radio/tv           5951
# 2        12  'critical/other existing credit'  education           2096
#
#        savings_status
# 0  'no known savings'
# 1                <100
# 2                <100

# %%
# Lista de linhas
df.iloc[[2,4,7,3,9,18,43], 0:9]
# Out:
#     duration              Historico de credito              purpose  \
# 2         12  'critical/other existing credit'            education
# 4         24              'delayed previously'            'new car'
# 7         36                   'existing paid'           'used car'
# 3         42                   'existing paid'  furniture/equipment
# 9         30  'critical/other existing credit'            'new car'
# 18        24                   'existing paid'           'used car'
# 43        30  'critical/other existing credit'           'used car'
#
#     credit_amount savings_status  employment  installment_commitment  \
# 2            2096           <100      4<=X<7                       2
# 4            4870           <100      1<=X<4                       3
# 7            6948           <100      1<=X<4                       2
# 3            7882           <100      4<=X<7                       2
# 9            5234           <100  unemployed                       4
# ...
